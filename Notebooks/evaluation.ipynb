# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_json("result_topics_df.json")

# %%
df
# Out:
#                                               paragraph  hour  day  month  \
# 0     תם שימוע ראש הממשלה, בינימין נתניהו: לאחר עשר ...    21    7     10
# 1     גבר בן שלושים נורה ברחוב העלייה בלוד, מצבו קשה...    21    7     10
# 2     הרמטכ"ל, רב אלוף אביב כוכבי, מזהיר הערב: "לא נ...    21    7     10
# 3     שר התחבורה בצלאל סמוטריץ' הודיע בעמוד הפייסבוק...    21    7     10
# 4     נשיא ארצות הברית טראמפ הודיע כי יציב קווים אדו...    21    7     10
# ...                                                 ...   ...  ...    ...
# 4737  הלימודים לא מתחדשים לפחות עד מחרתיים - רק הערב...     8    9      2
# 4738  בחירות אלפיים עשרים ואחת: יושב ראש ימינה חבר ה...     8    9      2
# 4739  המחדל בנבטים: במהלך הלילה אותרה הנקודה בגדר שמ...     8    9      2
# 4740  הדיונים על פתיחת המסחר באמצעות "הדרכון הירוק" ...     8    9      2
# 4741  פרסום ראשון: חיילת פנתה לרמטכ"ל בדרישה - פתח א...     8    9      2
#
#       year                                           filename          time  \
# 0     2019  /Users/sapir/PycharmProjects/hebnlp_project/da...  1.570482e+12
# 1     2019  /Users/sapir/PycharmProjects/hebnlp_project/da...  1.570482e+12
# 2     2019  /Users/sapir/PycharmProjects/hebnlp_project/da...  1.570482e+12
# 3     2019  /Users/sapir/PycharmProjects/hebnlp_project/da...  1.570482e+12
# 4     2019  /Users/sapir/PycharmProjects/hebnlp_project/da...  1.570482e+12
# ...    ...                                                ...           ...
# 4737  2021  /Users/sapir/PycharmProjects/hebnlp_project/da...  1.612858e+12
# 4738  2021  /Users/sapir/PycharmProjects/hebnlp_project/da...  1.612858e+12
# 4739  2021  /Users/sapir/PycharmProjects/hebnlp_project/da...  1.612858e+12
# 4740  2021  /Users/sapir/PycharmProjects/hebnlp_project/da...  1.612858e+12
# 4741  2021  /Users/sapir/PycharmProjects/hebnlp_project/da...  1.612858e+12
#
#                                         lemmatized_text  nemo_status  \
# 0     תם שימוע ממשלה ינימין נתניהו עשר דיון תיק אלף ...         True
# 1     גבר שלושים נורה רחוב עלייה לוד חובש מגן דוד אד...         True
# 2     רמטכ"ל רב אלוף כוכבי מזהיר הערב פגיעה התרחש הג...         True
# 3     שר תחבורה בצלאל סמוטריץ' הודיע עמוד פייסבוק בע...         True
# 4     נשיא ארץ ברית טראמפ הודיע הציב קו אדומי תורכי ...         True
# ...                                                 ...          ...
# 4737  לימודים התחדש מחרתיים הערב התכנס ועדה שר קורונ...         True
# 4738  בחירות אלפיים עשרים יושב ימינה כינס נפתל בנט ס...         True
# 4739  מחדל נבטי מהלך לילה אותר נקודה בגדר ככל נמלט ח...         True
# 4740  דיון פתיחה מסחר באמצעות דרכון ירוק נמשך הערב צ...         True
# 4741  פרסום חייל פנה רמטכ"ל דרישה פתח תפקיד יחידה עו...         True
#
#       Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0               0               7              0.6611
# 1               1               0              0.5212
# 2               2               5              0.8133
# 3               3               0              0.3446
# 4               4               7              0.3810
# ...           ...             ...                 ...
# 4737         4737               2              0.9757
# 4738         4738               4              0.9513
# 4739         4739               1              0.5740
# 4740         4740               2              0.9763
# 4741         4741               2              0.6518
#
#                                                Keywords
# 0     ממשלה, מדינה, נתניהו, ארץ_ברית, מפלגה, נשיא, ש...
# 1     משטרה, ירושלים, חלה, תאונה, רב, רכב, כביש, איש...
# 2     צה, שר, דיווח, ביטחון, משפט, גנץ, חייל, סוריה,...
# 3     משטרה, ירושלים, חלה, תאונה, רב, רכב, כביש, איש...
# 4     ממשלה, מדינה, נתניהו, ארץ_ברית, מפלגה, נשיא, ש...
# ...                                                 ...
# 4737  משרד, בריאות, קורונה, חינוך, מאה, חלה, שר, אלף...
# 4738  ממשלה, נתניהו, שר, גנץ, בנימין, מפלגה, מאה, יו...
# 4739  מאה, ישראלי, לילה, קורונה, שוחח, אלף, נשיא, רב...
# 4740  משרד, בריאות, קורונה, חינוך, מאה, חלה, שר, אלף...
# 4741  משרד, בריאות, קורונה, חינוך, מאה, חלה, שר, אלף...
#
# [4742 rows x 13 columns]

# %%
df.Dominant_Topic = df.Dominant_Topic.apply(lambda x : x+1)

# %% [markdown]
# # View examples

# %%
from pprint import pprint

# %%
topic_index = 3
topic_df = df[(df.Dominant_Topic == topic_index) & (df.Topic_Perc_Contrib > 0.9)]
# pprint(topic_df.paragraph.values.tolist())

# %% [markdown]
# # Get top paragraphs for each topic

# %%
sent_topics_sorteddf = pd.DataFrame()

sent_topics_outdf_grpd = df.groupby('Dominant_Topic')

for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf = pd.concat([sent_topics_sorteddf, 
                                             grp.sort_values(['Topic_Perc_Contrib'], ascending=[0]).head(5)], 
                                            axis=0)

# Reset Index    
sent_topics_sorteddf.reset_index(drop=True, inplace=True)

# %%
sent_topics_sorteddf.drop(["hour", "day", "month", "year", "filename", "time", "lemmatized_text", "nemo_status", "Document_No", "Keywords"], inplace=True, axis=1)

# %%
sent_topics_sorteddf
# Out:
#                                             paragraph  Dominant_Topic  \
# 0   20התרסקות מטוס הסנונית בנובמבר האחרון: מתחקיר ...               1
# 1   נכה צה"ל בן עשרים ושש הצית את עצמו במשרדי אגף ...               1
# 2   אלפי בני אדם מוחים בשעה זו בנצרת ובטמרה נגד הת...               1
# 3   21 משטרת הקפיטול בארצות הברית ביקשה להאריך את ...               1
# 4   21הסתדרות מרחב ירושלים הודיעה לעירייה על הפסקת...               1
# 5   21 שלוש שעות לסגירת הרשימות לכנסת העשרים וארבע...               2
# 6   <<\nנשיא ארצות הברית ג''ו ביידן הודיע כי הוא מ...               2
# 7   משפחתו של החייל משה תמם זכרונו לברכה, שנרצח בפ...               2
# 8   המופע של טראמפ: נשיא ארצות הברית קיים הלילה עצ...               2
# 9   <<\nכלת פרס ישראל בתחום חקר הספרות העברית והכל...               2
# 10  שרי הממשלה יאשרו הערב במשאל טלפוני מתווה חדש ל...               3
# 11  20 הממשלה אישרה פה אחד להאריך את הסגר בעשרה ימ...               3
# 12  ישראל, ארצות הברית, ושתיים עשרה מדינות נוספות,...               3
# 13  ועדת השרים לקורונה תתכנס היום שוב לדיון בהמשך ...               3
# 14  ועדת החוקה של הכנסת תתכנס בקרוב לדיון בחוק הכפ...               3
# 15  הפרקליטות החליטה לסגור את תיק החקירה נגד ראש ל...               4
# 16  המשטרה תבקש היום להאריך את מעצרם של שני הגברים...               4
# 17  שני ילדים נהרגו בשתי תאונות דרכים במהלך יום הכ...               4
# 18  חבר הכנסת עופר כסיף מהרשימה המשותפת סיים למסור...               4
# 19  סוכנת משטרתית סמויה שהתחזתה בחודשים האחרונים ל...               4
# 20  אלכסיי נבלני, מנהיג האופוזיציה של רוסיה, ייאסר...               5
# 21  21 יושב ראש מפלגת "כחול לבן", בני גנץ, קרא הער...               5
# 22  ראש הממשלה בנימין נתניהו קורא לאישור רכישת חיס...               5
# 23  21 עורך הדין דוד שמרון הגיש תביעת דיבה נגד דוד...               5
# 24  20שלוש שעות לסגירת הרשימות בבחירות לפרלמנט הפל...               5
# 25  הרמטכ״ל רב אלוף אביב כוכבי הנחה את צה״ל להכין ...               6
# 26  21 הותר לפרסום: הצעירה הישראלית שחצתה את הגבול...               6
# 27  קרב הגרסאות על תקיפת מפקד סיירת גולני במחאה על...               6
# 28  <<\nראש הממשלה בנימין נתניהו תקף בפתח ישיבת המ...               6
# 29  ארמון בקינגהאם בתגובה ראשונה לראיון של הנסיך ה...               6
# 30  הרשת החברתית פרלר parler שבה לפעילות לאחר חודש...               7
# 31  פייסבוק נגד חדשות הכזב: הרשת החברתית הודיעה כי...               7
# 32  21כוחות הביטחון בדרום מהדקים בימים אלה את שילו...               7
# 33  20 ירידה בהכנסות רכבת ישראל בשל הקורונה: הרכבת...               7
# 34  \t21משחקי המחזור האחרון של העונה הסדירה בליגת ...               7
# 35  היום תצא משלחת ישראלית אמריקנית למרוקו במסגרת ...               8
# 36  תגובות חריפות במערכת הפוליטית לקביעת בית הדין ...               8
# 37  היועץ המשפטי לממשלה אביחי מנדלבליט חוזר בו וקו...               8
# 38  21 השרה לאיכות הסביבה תקיים הערכת מצב לאחר שגו...               8
# 39  החלטת בית הדין הפלילי הבינלאומי בהאג לחקור את ...               8
#
#     Topic_Perc_Contrib
# 0               0.9844
# 1               0.9832
# 2               0.9825
# 3               0.9814
# 4               0.9810
# 5               0.9854
# 6               0.9841
# 7               0.9841
# 8               0.9821
# 9               0.9805
# 10              0.9891
# 11              0.9883
# 12              0.9877
# 13              0.9859
# 14              0.9854
# 15              0.9869
# 16              0.9846
# 17              0.9825
# 18              0.9821
# 19              0.9814
# 20              0.9861
# 21              0.9859
# 22              0.9854
# 23              0.9849
# 24              0.9846
# 25              0.9873
# 26              0.9849
# 27              0.9846
# 28              0.9838
# 29              0.9828
# 30              0.9838
# 31              0.9835
# 32              0.9835
# 33              0.9828
# 34              0.9817
# 35              0.9886
# 36              0.9873
# 37              0.9867
# 38              0.9867
# 39              0.9865

# %%
# sent_topics_sorteddf.to_csv("top_paras.csv")

# %% [markdown]
# # Events Evaluation

# %%
dti = pd.to_datetime(df[["year", "month", "day", "hour"]], errors="coerce")
df["time"] = dti

# %%
HEB_STOPWORDS_PATH = "../added_material/heb_stopwords.txt"
CUSTOM_STOPWORDS = [
    "בעקבות",
    "נמסר",
    "כתבתנו",
    "כתבנו",
    "הבוקר",
    "הלילה",
    "אמש",
    "לענייני",
    "מוסר",
    "מוסרת",
    "מוסרת",
    "כי",
    "כתב",
    "כתבת",
    "הערב",
    "בירושלים"
]

def remove_stopwords(s, stopwords):
    word_list = s.split()
    output = [w for w in word_list if not w in stopwords]
    return " ".join(output)

with open(HEB_STOPWORDS_PATH) as f:
    heb_stopwords = [x.rstrip() for x in f]

df.loc[:, "paragraph_no_stopwords"] = df.paragraph.apply(lambda x: remove_stopwords(x,
                                                                           CUSTOM_STOPWORDS + heb_stopwords))

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

def generate_word_cloud(time_df, font_path, file_name):
    text = " ".join(time_df.paragraph_no_stopwords.tolist())
    wordcloud = WordCloud(font_path=font_path, width=1000, height=700, background_color="white").generate(text)
    fig, ax = plt.subplots(figsize=[10,10])
    ax.imshow(wordcloud, interpolation='bilinear')
    ax.axis("off")
    fig.tight_layout(pad=0)
    fig.savefig(file_name, dpi=300)

time_delta = pd.Timedelta("5 day")
font_path = "/System/Library/Fonts/Supplemental/Arial.ttf"

def generate_topics_dist_graph(time_df, y_label, file_name):
    fig, ax = plt.subplots(figsize=(12,5))
    percentage = lambda i: len(i) / float(len(time_df)) * 100
    sns.barplot(x="Dominant_Topic", y="Dominant_Topic", data=time_df, ax=ax, estimator=percentage)
    ax.set_yticks(np.arange(0,40,5))
    ax.yaxis.set_major_formatter(plt.FuncFormatter('{:.0f}%'.format))
    ax.set_xlabel("Dominant Topic")
    ax.set_ylabel( y_label)
    ax.set_xticklabels(["1: Internal Affairs", "2: Misc.", "3: COVID", "4: Internal Affairs", "5: Politics", "6: Security", "7: Leisure", "8: Politics"])
    fig.tight_layout(pad=0)
    fig.savefig(file_name, dpi=300)
    
def generate_topics_dist_graph_comparative(time_df, all_df, event_name, file_name):
    fig, ax = plt.subplots(figsize=(12,5))
    time_counts = time_df.Dominant_Topic.value_counts().sort_index()
    time_percentages = time_counts.values / time_counts.sum() * 100
    all_counts = all_df.Dominant_Topic.value_counts().sort_index()
    all_percentages = all_counts.values / all_counts.sum() * 100
    ax.bar(np.arange(1,9), time_percentages, 1/3 ,color='red',label=event_name, align='edge')
    ax.bar(np.arange(1,9)-1/3, all_percentages, 1/3 ,color='b',label='All Data',align='edge')
    ax.legend()
    ax.set_xlabel("Dominant Topic")
    ax.set_ylabel("Percent of Paragraphs")
    ax.yaxis.set_major_formatter(plt.FuncFormatter('{:.0f}%'.format))
    ax.set_xticklabels(["blank", "1: Internal Affairs", "2: Misc.", "3: COVID", "4: Internal Affairs", "5: Politics", "6: Security", "7: Leisure", "8: Politics"])
    fig.tight_layout(pad=0)
    fig.savefig(file_name, dpi=300)

# %% [markdown]
# # Topics Distrubution in Data

# %%
generate_topics_dist_graph(df, "Count in All Data", "all_data_distribution2.png")

# %% [markdown]
# ## 9/4/2019 - first elections

# %%
event_time = pd.Timestamp("2019-04-09 00:00:00")
first_elections_df = df[(df["time"] >= event_time - time_delta) & (df["time"] <= event_time + time_delta)]
generate_word_cloud(first_elections_df, font_path, "09042019.png")

# %%
generate_topics_dist_graph_comparative(first_elections_df, df, "First Elections", "first_elections_distribution.png")
# Out:
# <ipython-input-15-999e8bf2954b>:42: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(["blank", "1: Internal Affairs", "2: Misc.", "3: COVID", "4: Internal Affairs", "5: Politics", "6: Security", "7: Leisure", "8: Politics"])

# %% [markdown]
# ## 12/11/2019 - missle attack at Israel after assassination of Jihad terrorist

# %%
event_time = pd.Timestamp("2019-11-12 00:00:00")
first_elections_df = df[(df["time"] >= event_time - time_delta) & (df["time"] <= event_time + time_delta)]
generate_word_cloud(first_elections_df, font_path, "12112019.png")

# %%
generate_topics_dist_graph_comparative(first_elections_df, df, "2019 Rocket Attack", "rocket_attack_distribution.png")
# Out:
# <ipython-input-15-999e8bf2954b>:42: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(["blank", "1: Internal Affairs", "2: Misc.", "3: COVID", "4: Internal Affairs", "5: Politics", "6: Security", "7: Leisure", "8: Politics"])

# %% [markdown]
# ## 2/3/2020 - third elections

# %%
event_time = pd.Timestamp("2020-03-02 00:00:00")
first_elections_df = df[(df["time"] >= event_time - time_delta) & (df["time"] <= event_time + time_delta)]
generate_word_cloud(first_elections_df, font_path, "02032019.png")

# %%
generate_topics_dist_graph_comparative(first_elections_df, df, "Third Elections 2020", "third_elections_distribution.png")
# Out:
# <ipython-input-15-999e8bf2954b>:42: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(["blank", "1: Internal Affairs", "2: Misc.", "3: COVID", "4: Internal Affairs", "5: Politics", "6: Security", "7: Leisure", "8: Politics"])

# %% [markdown]
# # 8/4/2020 - first quarantine

# %%
event_time = pd.Timestamp("2020-04-08 00:00:00")
first_elections_df = df[(df["time"] >= event_time - time_delta) & (df["time"] <= event_time + time_delta)]
generate_word_cloud(first_elections_df, font_path, "08042019.png")

# %%
time_df = first_elections_df
all_df = df
event_name = "First Quarantine"
file_name = "first_quarantine_distribution.png"

fig, ax = plt.subplots(figsize=(12,5))
time_counts = time_df.Dominant_Topic.value_counts().sort_index()
time_percentages = time_counts.values / time_counts.sum() * 100
all_counts = all_df.Dominant_Topic.value_counts().sort_index()
all_percentages = all_counts.values / all_counts.sum() * 100
ax.bar(np.array([1,2,3,5,6,7,8]), time_percentages, 1/3 ,color='red',label=event_name, align='edge')
ax.bar(np.arange(1,9)-1/3, all_percentages, 1/3 ,color='b',label='All Data',align='edge')
ax.legend()
ax.set_xlabel("Dominant Topic")
ax.set_ylabel("Percent of Paragraphs")
ax.yaxis.set_major_formatter(plt.FuncFormatter('{:.0f}%'.format))
ax.set_xticklabels(["blank", "1: Internal Affairs", "2: Misc.", "3: COVID", "4: Internal Affairs", "5: Politics", "6: Security", "7: Leisure", "8: Politics"])
fig.tight_layout(pad=0)
fig.savefig(file_name, dpi=300)
# Out:
# <ipython-input-24-e2f5ecd2824f>:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(["blank", "1: Internal Affairs", "2: Misc.", "3: COVID", "4: Internal Affairs", "5: Politics", "6: Security", "7: Leisure", "8: Politics"])

# %% [markdown]
# # Comparison between before COVID and after

# %%
first_covid_case = pd.Timestamp("2020-02-27 00:00:00")
df_before_covid = df[df.time < first_covid_case]
df_after_covid = df[df.time >= first_covid_case]

time_df = df_before_covid
all_df = df_after_covid
event_name = "Before first COVID case"
file_name = "before_after_covid_comparison.png"

fig, ax = plt.subplots(figsize=(12,5))
time_counts = time_df.Dominant_Topic.value_counts().sort_index()
time_percentages = time_counts.values / time_counts.sum() * 100
all_counts = all_df.Dominant_Topic.value_counts().sort_index()
all_percentages = all_counts.values / all_counts.sum() * 100
ax.bar(np.arange(1,9), time_percentages, 1/3 ,color='red',label=event_name, align='edge')
ax.bar(np.arange(1,9)-1/3, all_percentages, 1/3 ,color='b',label='After first COVID case',align='edge')
ax.legend()
ax.set_xlabel("Dominant Topic")
ax.set_ylabel("Percent of Paragraphs")
ax.yaxis.set_major_formatter(plt.FuncFormatter('{:.0f}%'.format))
ax.set_xticklabels(["blank", "1: Internal Affairs", "2: Misc.", "3: COVID", "4: Internal Affairs", "5: Politics", "6: Security", "7: Leisure", "8: Politics"])
fig.tight_layout(pad=0)
fig.savefig(file_name, dpi=300)
# Out:
# <ipython-input-25-3b2a9a8b2f9b>:21: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(["blank", "1: Internal Affairs", "2: Misc.", "3: COVID", "4: Internal Affairs", "5: Politics", "6: Security", "7: Leisure", "8: Politics"])

# %%
from datetime import datetime


DATE_TIME_FORMAT = '%Y-%m-%d'
START_DATE = '2019-01-01'
END_DATE = '2021-04-01'
start_datetime = datetime.strptime(START_DATE, DATE_TIME_FORMAT)
end_datetime = datetime.strptime(END_DATE, DATE_TIME_FORMAT)

timedelta_index = pd.date_range(start=start_datetime, end=end_datetime, freq='M').to_series()
dts = []
for index, value in timedelta_index.iteritems():
    dt = index.to_pydatetime()
    dts.append(dt)

# %%
dts
# Out:
# [datetime.datetime(2019, 1, 31, 0, 0),
#  datetime.datetime(2019, 2, 28, 0, 0),
#  datetime.datetime(2019, 3, 31, 0, 0),
#  datetime.datetime(2019, 4, 30, 0, 0),
#  datetime.datetime(2019, 5, 31, 0, 0),
#  datetime.datetime(2019, 6, 30, 0, 0),
#  datetime.datetime(2019, 7, 31, 0, 0),
#  datetime.datetime(2019, 8, 31, 0, 0),
#  datetime.datetime(2019, 9, 30, 0, 0),
#  datetime.datetime(2019, 10, 31, 0, 0),
#  datetime.datetime(2019, 11, 30, 0, 0),
#  datetime.datetime(2019, 12, 31, 0, 0),
#  datetime.datetime(2020, 1, 31, 0, 0),
#  datetime.datetime(2020, 2, 29, 0, 0),
#  datetime.datetime(2020, 3, 31, 0, 0),
#  datetime.datetime(2020, 4, 30, 0, 0),
#  datetime.datetime(2020, 5, 31, 0, 0),
#  datetime.datetime(2020, 6, 30, 0, 0),
#  datetime.datetime(2020, 7, 31, 0, 0),
#  datetime.datetime(2020, 8, 31, 0, 0),
#  datetime.datetime(2020, 9, 30, 0, 0),
#  datetime.datetime(2020, 10, 31, 0, 0),
#  datetime.datetime(2020, 11, 30, 0, 0),
#  datetime.datetime(2020, 12, 31, 0, 0),
#  datetime.datetime(2021, 1, 31, 0, 0),
#  datetime.datetime(2021, 2, 28, 0, 0),
#  datetime.datetime(2021, 3, 31, 0, 0)]

# %%
dfs = []
for dt in dts:
    dfs.append(df[(df['time'].dt.month == dt.month) & (df['time'].dt.year == dt.year)])

# %%
import matplotlib.dates as mdates
def create_timeplot_for_topics(dfs, dts, topic_num, y_axis, file_name):
    percentages = []
    for data in dfs:
        percentages.append(len(data[data.Dominant_Topic == topic_num]) / len(data) * 100)
    f, ax = plt.subplots(figsize=[20,10])
    sns.set_context('paper', font_scale=2.2)
    df_topic = df[df.Dominant_Topic == topic_num]
    sns.lineplot(x=dts, y=percentages, linewidth = 15)

    ax.set_xlabel("Time")
    ax.set_ylabel(y_axis)


    # Major ticks every 6 months.
    fmt_half_year = mdates.MonthLocator(interval=1)
    ax.xaxis.set_major_locator(fmt_half_year)

    # Minor ticks every month.
    fmt_month = mdates.DayLocator(interval=4)
    ax.xaxis.set_minor_locator(fmt_month)

    # Text in the x axis will be displayed in 'YYYY-mm' format.
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%y'))

    # Format the coords message box, i.e. the numbers displayed as the cursor moves
    # across the axes within the interactive GUI.
    ax.format_xdata = mdates.DateFormatter('%d-%m-%y')
    ax.grid(True)
    ax.yaxis.set_major_formatter(plt.FuncFormatter('{:.0f}%'.format))


    # Rotates and right aligns the x labels, and moves the bottom of the
    # axes up to make room for them.
    f.autofmt_xdate()
    f.savefig(file_name, dpi=300)

# %%
create_timeplot_for_topics(dfs, dts, 3, "Topic 3 (COVID-related) Paragraphs", "COVID_timeline.png")

# %%
create_timeplot_for_topics(dfs, dts, 8, "Topic 8 - Politics, election related", "elections_timeline.png")

# %%
create_timeplot_for_topics(dfs, dts, 6, "Topic 6 - security", "security_timeline.png")
